// %% [markdown]
// ## Using parameters `norm`, `vmain`, `vmax`  in `geomImshow()`
//
// You can use parameters `norm`, `vmain`, `vmax` when rendering grayscale images.
//
// A grayscale image is specified by 2D array where each element's value
// represents the luminance of corresponding pixel in the image.

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="VE7yHB"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.0.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("VE7yHB").appendChild(div);
//            };
//            var e = document.getElementById("VE7yHB");
//            e.appendChild(script);
//        })();
//    </script>

// %%
// Generate 2D arrays. 
// First two arrays both contain float numbers but have different range of values.
// The 3rd array contains int-s.
fun linspace(start: Double, end: Double, count: Int): List<Number> {
    val step = (end - start) / (count - 1)
    return mutableListOf<Double>() + 
        start + (1 .. (count - 2)).map { i -> start + i * step } + end
}

val arr_f0 = RasterData.create(listOf(linspace(0.3, 0.7, 30)))
val arr_f1 = RasterData.create(listOf(linspace(30.0, 170.0, 30)))
val arr_i = RasterData.create(listOf(linspace(30.0, 170.0, 30).map { it.toInt() }))

// %%
// Setup suitable plot options for the demo.
val p = (letsPlot() + ggsize(450, 60) + geomRect(xmin=-0.5, ymin=-0.5, xmax=29.5, ymax=0.5, color="black", alpha=0) + 
coordCartesian() + themeClassic() + theme(axis="blank"))

// %% [markdown]
// #### Image normalization
//
// By default, `geomImshow()` applies a linear scaling to transform data values to range [0-255].

// %%
(p + geomImshow(arr_f0)).show()
(p + geomImshow(arr_f1)).show()
(p + geomImshow(arr_i)).show()
// Out:
//    <div id="sOuOAe"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("sOuOAe");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="KvsnL3"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("KvsnL3");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="s60Z2i"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("s60Z2i");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ##
//
// You can disable image normalization using the `norm` parameter.

// %%
(p + geomImshow(arr_f0, norm=false)).show()
(p + geomImshow(arr_f1, norm=false)).show()
(p + geomImshow(arr_i, norm=false)).show()
// Out:
//    <div id="tGOa0j"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("tGOa0j");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="FYrjbh"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("FYrjbh");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="dNrgRO"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("dNrgRO");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// #### Define normalization range using `vmin, vmax` parameters

// %%
// Set upper limit less than the data max value.
(p + geomImshow(arr_f0, vmax=.5)).show()
(p + geomImshow(arr_f1, vmax=100)).show()
(p + geomImshow(arr_i, vmax=100)).show()
// Out:
//    <div id="v2qoNh"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("v2qoNh");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="EzynXM"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("EzynXM");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="auO1ME"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("auO1ME");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// Set limits wider than the data entire range.
(p + geomImshow(arr_f0, vmin=.4, vmax=.6)).show()
(p + geomImshow(arr_f1, vmin=70, vmax=120)).show()
(p + geomImshow(arr_i, vmin=50, vmax=150)).show()
// Out:
//    <div id="BYNBOx"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("BYNBOx");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="ckp9Ie"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("ckp9Ie");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="1rJarY"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "show_legend":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("1rJarY");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
