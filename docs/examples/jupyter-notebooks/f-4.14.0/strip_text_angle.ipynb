// %% [raw]
// {
//  "cells": [
//   {
//    "cell_type": "markdown",
//    "id": "29ef1d2f",
//    "metadata": {},
//    "source": [
//     "# Facet Strip Text Angle\n",
//     "\n",
//     "Facet strip labels can be rotated with the `angle` parameter in `elementText()`. Use `stripTextX` for horizontal facet labels and `stripTextY` for vertical facet labels. Use `stripText` to change both.\n"
//    ]
//   },
//   {
//    "cell_type": "code",
//    "execution_count": 1,
//    "id": "166638f5",
//    "metadata": {},
//    "outputs": [
//     {
//      "data": {
//       "text/html": [
//        "   <div id=\"JjmpZr\"></div>\n",
//        "   <script type=\"text/javascript\" data-lets-plot-script=\"library\">\n",
//        "       if(!window.letsPlotCallQueue) {\n",
//        "           window.letsPlotCallQueue = [];\n",
//        "       }; \n",
//        "       window.letsPlotCall = function(f) {\n",
//        "           window.letsPlotCallQueue.push(f);\n",
//        "       };\n",
//        "       (function() {\n",
//        "           var script = document.createElement(\"script\");\n",
//        "           script.type = \"text/javascript\";\n",
//        "           script.src = \"https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.10.1/js-package/distr/lets-plot.min.js\";\n",
//        "           script.onload = function() {\n",
//        "               window.letsPlotCall = function(f) {f();};\n",
//        "               window.letsPlotCallQueue.forEach(function(f) {f();});\n",
//        "               window.letsPlotCallQueue = [];\n",
//        "               \n",
//        "               \n",
//        "           };\n",
//        "           script.onerror = function(event) {\n",
//        "               window.letsPlotCall = function(f) {};\n",
//        "               window.letsPlotCallQueue = [];\n",
//        "               var div = document.createElement(\"div\");\n",
//        "               div.style.color = 'darkred';\n",
//        "               div.textContent = 'Error loading Lets-Plot JS';\n",
//        "               document.getElementById(\"JjmpZr\").appendChild(div);\n",
//        "           };\n",
//        "           var e = document.getElementById(\"JjmpZr\");\n",
//        "           e.appendChild(script);\n",
//        "       })();\n",
//        "   </script>"
//       ]
//      },
//      "metadata": {},
//      "output_type": "display_data"
//     },
//     {
//      "data": {
//       "text/html": [
//        "            <div id=\"kotlin_out_0\"></div>\n",
//        "            <script type=\"text/javascript\">\n",
//        "                            if(!window.kotlinQueues) {\n",
//        "                window.kotlinQueues = {};\n",
//        "            }\n",
//        "            if(!window.kotlinQueues[\"letsPlotJs\"]) {\n",
//        "                var resQueue = [];\n",
//        "                window.kotlinQueues[\"letsPlotJs\"] = resQueue;\n",
//        "                window[\"call_letsPlotJs\"] = function(f) {\n",
//        "                    resQueue.push(f);\n",
//        "                }\n",
//        "            }\n",
//        "            (function (){\n",
//        "                var modifiers = [(function(script) {\n",
//        "    script.src = \"https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.10.1/js-package/distr/lets-plot.min.js\"\n",
//        "    script.type = \"text/javascript\";\n",
//        "})];\n",
//        "                var e = document.getElementById(\"kotlin_out_0\");\n",
//        "                modifiers.forEach(function (gen) {\n",
//        "                    var script = document.createElement(\"script\");\n",
//        "                    gen(script)\n",
//        "                    script.addEventListener(\"load\", function() {\n",
//        "                        window[\"call_letsPlotJs\"] = function(f) {f();};\n",
//        "                        window.kotlinQueues[\"letsPlotJs\"].forEach(function(f) {f();});\n",
//        "                        window.kotlinQueues[\"letsPlotJs\"] = [];\n",
//        "                    }, false);\n",
//        "                    script.addEventListener(\"error\", function() {\n",
//        "                        window[\"call_letsPlotJs\"] = function(f) {};\n",
//        "                        window.kotlinQueues[\"letsPlotJs\"] = [];\n",
//        "                        var div = document.createElement(\"div\");\n",
//        "                        div.style.color = 'darkred';\n",
//        "                        div.textContent = 'Error loading resource letsPlotJs';\n",
//        "                        document.getElementById(\"kotlin_out_0\").appendChild(div);\n",
//        "                    }, false);\n",
//        "                    \n",
//        "                    e.appendChild(script);\n",
//        "                });\n",
//        "            })();\n",
//        "            </script>"
//       ]
//      },
//      "metadata": {},
//      "output_type": "display_data"
//     }
//    ],
//    "source": [
//     "%use lets-plot"
//    ]
//   },
//   {
//    "cell_type": "code",
//    "execution_count": 2,
//    "id": "acb0a36f-db8b-471c-809d-15ad1ab04696",
//    "metadata": {},
//    "outputs": [
//     {
//      "data": {
//       "text/plain": [
//        "Lets-Plot Kotlin API v.4.14.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.10.1.\n",
//        "Outputs: Web (HTML+JS), Static SVG (hidden)"
//       ]
//      },
//      "execution_count": 2,
//      "metadata": {},
//      "output_type": "execute_result"
//     }
//    ],
//    "source": [
//     "LetsPlot.getInfo()"
//    ]
//   },
//   {
//    "cell_type": "code",
//    "execution_count": 3,
//    "id": "346b37c8",
//    "metadata": {},
//    "outputs": [],
//    "source": [
//     "val mtcars = mapOf(\n",
//     "    \"mpg\" to listOf(21.0, 21.0, 22.8, 21.4, 18.7, 18.1, 14.3, 24.4, 22.8, 19.2, 17.8, 16.4),\n",
//     "    \"wt\" to listOf(2.620, 2.875, 2.320, 3.215, 3.440, 3.460, 3.570, 3.190, 3.150, 3.440, 3.440, 4.070),\n",
//     "    \"cyl\" to listOf(\"6\", \"6\", \"4\", \"6\", \"8\", \"6\", \"8\", \"4\", \"4\", \"6\", \"6\", \"8\")\n",
//     ")"
//    ]
//   },
//   {
//    "cell_type": "markdown",
//    "id": "a9ae2b4d",
//    "metadata": {},
//    "source": [
//     "## Horizontal Y-Axis Strip Labels\n",
//     "\n",
//     "By default, y-axis strip labels are vertical. When the labels are short, it may be more convenient to display them horizontally.\n"
//    ]
//   },
//   {
//    "cell_type": "code",
//    "execution_count": 4,
//    "id": "1b2c6a6e",
//    "metadata": {},
//    "outputs": [
//     {
//      "data": {
//       "text/html": [
//        "   <div id=\"pJUVOM\"></div>\n",
//        "   <script type=\"text/javascript\" data-lets-plot-script=\"library\">\n",
//        "       if(!window.letsPlotCallQueue) {\n",
//        "           window.letsPlotCallQueue = [];\n",
//        "       }; \n",
//        "       window.letsPlotCall = function(f) {\n",
//        "           window.letsPlotCallQueue.push(f);\n",
//        "       };\n",
//        "       (function() {\n",
//        "           var script = document.createElement(\"script\");\n",
//        "           script.type = \"text/javascript\";\n",
//        "           script.src = \"https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.10.1/js-package/distr/lets-plot.min.js\";\n",
//        "           script.onload = function() {\n",
//        "               window.letsPlotCall = function(f) {f();};\n",
//        "               window.letsPlotCallQueue.forEach(function(f) {f();});\n",
//        "               window.letsPlotCallQueue = [];\n",
//        "               \n",
//        "               \n",
//        "           };\n",
//        "           script.onerror = function(event) {\n",
//        "               window.letsPlotCall = function(f) {};\n",
//        "               window.letsPlotCallQueue = [];\n",
//        "               var div = document.createElement(\"div\");\n",
//        "               div.style.color = 'darkred';\n",
//        "               div.textContent = 'Error loading Lets-Plot JS';\n",
//        "               document.getElementById(\"pJUVOM\").appendChild(div);\n",
//        "           };\n",
//        "           var e = document.getElementById(\"pJUVOM\");\n",
//        "           e.appendChild(script);\n",
//        "       })();\n",
//        "   </script>"
//       ]
//      },
//      "metadata": {},
//      "output_type": "display_data"
//     },
//     {
//      "data": {
//       "text/html": [
//        "   <div id=\"ePBucZ\" ></div>\n",
//        "   <script type=\"text/javascript\" data-lets-plot-script=\"plot\">\n",
//        "   \n",
//        "   (function() {\n",
//        "   // ----------\n",
//        "   \n",
//        "   const forceImmediateRender = false;\n",
//        "   const responsive = false;\n",
//        "   \n",
//        "   let sizing = {\n",
//        "       width_mode: \"MIN\",\n",
//        "       height_mode: \"SCALED\",\n",
//        "       width: null, \n",
//        "       height: null \n",
//        "   };\n",
//        "   \n",
//        "   const preferredWidth = document.body.dataset.letsPlotPreferredWidth;\n",
//        "   if (preferredWidth !== undefined) {\n",
//        "       sizing = {\n",
//        "           width_mode: 'FIXED',\n",
//        "           height_mode: 'SCALED',\n",
//        "           width: parseFloat(preferredWidth)\n",
//        "       };\n",
//        "   }\n",
//        "   \n",
//        "   const containerDiv = document.getElementById(\"ePBucZ\");\n",
//        "   let fig = null;\n",
//        "   \n",
//        "   function renderPlot() {\n",
//        "       if (fig === null) {\n",
//        "           const plotSpec = {\n",
//        "\"ggtitle\":{\n",
//        "\"text\":\"Default strip label appearance\"\n",
//        "},\n",
//        "\"mapping\":{\n",
//        "\"x\":\"mpg\",\n",
//        "\"y\":\"wt\"\n",
//        "},\n",
//        "\"data\":{\n",
//        "\"mpg\":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,16.4],\n",
//        "\"cyl\":[\"6\",\"6\",\"4\",\"6\",\"8\",\"6\",\"8\",\"4\",\"4\",\"6\",\"6\",\"8\"],\n",
//        "\"wt\":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,4.07]\n",
//        "},\n",
//        "\"ggsize\":{\n",
//        "\"width\":500.0,\n",
//        "\"height\":300.0\n",
//        "},\n",
//        "\"kind\":\"plot\",\n",
//        "\"scales\":[],\n",
//        "\"layers\":[{\n",
//        "\"mapping\":{\n",
//        "},\n",
//        "\"stat\":\"identity\",\n",
//        "\"color\":\"steelblue\",\n",
//        "\"position\":\"identity\",\n",
//        "\"geom\":\"point\",\n",
//        "\"data\":{\n",
//        "}\n",
//        "}],\n",
//        "\"theme\":{\n",
//        "\"name\":\"bw\",\n",
//        "\"strip_background_y\":{\n",
//        "\"fill\":\"aliceblue\",\n",
//        "\"color\":\"steelblue\",\n",
//        "\"blank\":false\n",
//        "},\n",
//        "\"panel_border\":{\n",
//        "\"color\":\"gray20\",\n",
//        "\"blank\":false\n",
//        "}\n",
//        "},\n",
//        "\"facet\":{\n",
//        "\"name\":\"grid\",\n",
//        "\"y\":\"cyl\",\n",
//        "\"x_order\":1.0,\n",
//        "\"y_order\":1.0\n",
//        "},\n",
//        "\"data_meta\":{\n",
//        "\"series_annotations\":[{\n",
//        "\"type\":\"float\",\n",
//        "\"column\":\"mpg\"\n",
//        "},{\n",
//        "\"type\":\"float\",\n",
//        "\"column\":\"wt\"\n",
//        "},{\n",
//        "\"type\":\"str\",\n",
//        "\"column\":\"cyl\"\n",
//        "}]\n",
//        "},\n",
//        "\"spec_id\":\"1\"\n",
//        "};\n",
//        "           window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });\n",
//        "       } else {\n",
//        "           fig.updateView({});\n",
//        "       }\n",
//        "   }\n",
//        "   \n",
//        "   const renderImmediately = \n",
//        "       forceImmediateRender || (\n",
//        "           sizing.width_mode === 'FIXED' && \n",
//        "           (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')\n",
//        "       );\n",
//        "   \n",
//        "   if (renderImmediately) {\n",
//        "       renderPlot();\n",
//        "   }\n",
//        "   \n",
//        "   if (!renderImmediately || responsive) {\n",
//        "       // Set up observer for initial sizing or continuous monitoring\n",
//        "       var observer = new ResizeObserver(function(entries) {\n",
//        "           for (let entry of entries) {\n",
//        "               if (entry.contentBoxSize && \n",
//        "                   entry.contentBoxSize[0].inlineSize > 0) {\n",
//        "                   if (!responsive && observer) {\n",
//        "                       observer.disconnect();\n",
//        "                       observer = null;\n",
//        "                   }\n",
//        "                   renderPlot();\n",
//        "                   if (!responsive) {\n",
//        "                       break;\n",
//        "                   }\n",
//        "               }\n",
//        "           }\n",
//        "       });\n",
//        "       \n",
//        "       observer.observe(containerDiv);\n",
//        "   }\n",
//        "   \n",
//        "   // ----------\n",
//        "   })();\n",
//        "   \n",
//        "   </script>                <svg xmlns=\"http://www.w3.org/2000/svg\" xmlns:xlink=\"http://www.w3.org/1999/xlink\" display=\"block\" class=\"plt-container\" id=2ecde286-417f-4e2d-9ff3-f5e95c6bae89 width=\"100%\" height=\"100%\" style=\"max-width: 500.0px; max-height: 300.0px;\" viewBox=\"0 0 500.0 300.0\" preserveAspectRatio=\"xMinYMin meet\">\n",
//        "  <style type=\"text/css\">\n",
//        "  .plt-container {\n",
//        "   font-family: sans-serif;\n",
//        "   user-select: none;\n",
//        "   -webkit-user-select: none;\n",
//        "   -moz-user-select: none;\n",
//        "   -ms-user-select: none;\n",
//        "}\n",
//        "text {\n",
//        "   text-rendering: optimizeLegibility;\n",
//        "}\n",
//        "#px5Te8d .plot-title {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 16.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .plot-subtitle {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 15.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .plot-caption {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .plot-tag {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 16.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .hyperlink-element {\n",
//        "fill:#118ed8;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .legend-title {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 15.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .legend-item {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .axis-title-x {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 15.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .axis-text-x {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#dwVrPQw .axis-tooltip-text-x {\n",
//        "fill:#ffffff;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .axis-title-y {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 15.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .axis-text-y {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#dwVrPQw .axis-tooltip-text-y {\n",
//        "fill:#ffffff;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .facet-strip-text-x {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#px5Te8d .facet-strip-text-y {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#dwVrPQw .tooltip-text {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#dwVrPQw .tooltip-title {\n",
//        "fill:#474747;\n",
//        "font-weight: bold;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#dwVrPQw .tooltip-label {\n",
//        "fill:#474747;\n",
//        "font-weight: bold;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "\n",
//        "  </style>\n",
//        "  <g id=\"px5Te8d\">\n",
//        "    <path fill-rule=\"evenodd\" fill=\"rgb(255,255,255)\" fill-opacity=\"1.0\" d=\"M0.0 0.0 L0.0 300.0 L500.0 300.0 L500.0 0.0 Z\">\n",
//        "    </path>\n",
//        "    <g transform=\"translate(21.0 22.0 ) \">\n",
//        "      <g>\n",
//        "        <rect x=\"13.980605455468202\" y=\"0.0\" height=\"72.66666666666667\" width=\"440.0193945445318\" fill=\"rgb(255,255,255)\" fill-opacity=\"1.0\">\n",
//        "        </rect>\n",
//        "        <g transform=\"translate(13.980605455468202 0.0 ) \">\n",
//        "          <g>\n",
//        "            <line x1=\"47.72487582593703\" y1=\"0.0\" x2=\"47.72487582593703\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"126.93628798516875\" y1=\"0.0\" x2=\"126.93628798516875\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"206.14770014440035\" y1=\"0.0\" x2=\"206.14770014440035\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"285.35911230363206\" y1=\"0.0\" x2=\"285.35911230363206\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"364.5705244628638\" y1=\"0.0\" x2=\"364.5705244628638\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"8
 72.66666666666667)]\">\n",
//        "        <g transform=\"translate(13.980605455468202 165.33333333333334 ) \">\n",
//        "          <g>\n",
//        "            <g buffered-rendering=\"static\">\n",
//        "              <g>\n",
//        "                <g >\n",
//        "                  <circle fill=\"#4682b4\" stroke=\"#000000\" stroke-opacity=\"0.0\" stroke-width=\"0.0\" cx=\"194.2659883205156\" cy=\"27.084848484848493\" r=\"3.3000000000000003\" />\n",
//        "                  <circle fill=\"#4682b4\" stroke=\"#000000\" stroke-opacity=\"0.0\" stroke-width=\"0.0\" cx=\"20.000881570206047\" cy=\"22.177489177489207\" r=\"3.3000000000000003\" />\n",
//        "                  <circle fill=\"#4682b4\" stroke=\"#000000\" stroke-opacity=\"0.0\" stroke-width=\"0.0\" cx=\"103.17286433739912\" cy=\"3.3030303030303116\" r=\"3.3000000000000003\" />\n",
//        "                </g>\n",
//        "              </g>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "        </g>\n",
//        "        <defs>\n",
//        "          <clipPath id=\"cDvADGn\">\n",
//        "            <rect x=\"13.980605455468202\" y=\"165.33333333333334\" width=\"440.0193945445318\" height=\"72.66666666666667\">\n",
//        "            </rect>\n",
//        "          </clipPath>\n",
//        "        </defs>\n",
//        "      </g>\n",
//        "      <g>\n",
//        "        <g transform=\"translate(13.980605455468202 238.0 ) \">\n",
//        "          <g transform=\"translate(8.119169746321177 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>14</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(87.33058190555289 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>16</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(166.5419940647846 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>18</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(245.7534062240162 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>20</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(324.9648183832479 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>22</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(404.17623054247963 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>24</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "        </g>\n",
//        "        <g transform=\"translate(13.980605455468202 165.33333333333334 ) \">\n",
//        "          <g transform=\"translate(0.0 43.6943722943723 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"-4.0\" y2=\"0.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(-6.0 0.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-y\" text-anchor=\"end\" dy=\"0.35em\">\n",
//        "                <tspan>3</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(0.0 5.945454545454567 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"-4.0\" y2=\"0.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(-6.0 0.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-y\" text-anchor=\"end\" dy=\"0.35em\">\n",
//        "                <tspan>4</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "        </g>\n",
//        "        <rect x=\"13.980605455468202\" y=\"165.33333333333334\" height=\"72.66666666666667\" width=\"440.0193945445318\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" stroke-width=\"1.0\" fill-opacity=\"0.0\">\n",
//        "        </rect>\n",
//        "        <rect x=\"13.980605455468202\" y=\"165.33333333333334\" height=\"72.66666666666667\" width=\"440.0193945445318\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" stroke-width=\"1.0\" fill-opacity=\"0.0\">\n",
//        "        </rect>\n",
//        "      </g>\n",
//        "      <rect x=\"454.0\" y=\"165.33333333333334\" height=\"72.66666666666667\" width=\"19.0\" stroke-width=\"1.0\" fill=\"rgb(240,248,255)\" fill-opacity=\"1.0\" stroke=\"rgb(70,130,180)\" stroke-opacity=\"1.0\">\n",
//        "      </rect>\n",
//        "      <g transform=\"translate(459.6 201.66666666666669 ) rotate(90.0 ) \">\n",
//        "        <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"facet-strip-text-y\" text-anchor=\"middle\">\n",
//        "          <tspan>8</tspan>\n",
//        "        </text>\n",
//        "      </g>\n",
//        "    </g>\n",
//        "    <g transform=\"translate(34.9806054554682 15.8 ) \">\n",
//        "      <text style=\"font-size:16.0px;\" y=\"0.0\" class=\"plot-title\">\n",
//        "        <tspan>Default strip label appearance</tspan>\n",
//        "      </text>\n",
//        "    </g>\n",
//        "    <g transform=\"translate(15.0 141.0 ) rotate(-90.0 ) \">\n",
//        "      <text style=\"font-size:15.0px;\" y=\"0.0\" class=\"axis-title-y\" text-anchor=\"middle\">\n",
//        "        <tspan>wt</tspan>\n",
//        "      </text>\n",
//        "    </g>\n",
//        "    <g transform=\"translate(254.9903027277341 294.0 ) \">\n",
//        "      <text style=\"font-size:15.0px;\" y=\"0.0\" class=\"axis-title-x\" text-anchor=\"middle\">\n",
//        "        <tspan>mpg</tspan>\n",
//        "      </text>\n",
//        "    </g>\n",
//        "    <path fill=\"rgb(0,0,0)\" fill-opacity=\"0.0\" stroke=\"rgb(71,71,71)\" stroke-opacity=\"1.0\" stroke-width=\"0.0\" d=\"M0.0 0.0 L0.0 300.0 L500.0 300.0 L500.0 0.0 Z\" pointer-events=\"none\">\n",
//        "    </path>\n",
//        "  </g>\n",
//        "  <g id=\"dwVrPQw\">\n",
//        "  </g>\n",
//        "</svg>\n",
//        "                <script>document.getElementById(\"2ecde286-417f-4e2d-9ff3-f5e95c6bae89\").style.display = \"none\";</script>"
//       ]
//      },
//      "execution_count": 4,
//      "metadata": {},
//      "output_type": "execute_result"
//     }
//    ],
//    "source": [
//     "val basePlot = letsPlot(mtcars) { x = \"mpg\"; y = \"wt\" } +\n",
//     "    geomPoint(color = \"steelblue\") +\n",
//     "    facetGrid(y = \"cyl\") +\n",
//     "    themeBW() +\n",
//     "    theme(\n",
//     "        panelBorder = elementRect(color = \"gray20\"),\n",
//     "        stripBackgroundY = elementRect(fill = \"aliceblue\", color = \"steelblue\")\n",
//     "    ) +\n",
//     "    ggtitle(\"Default strip label appearance\") +\n",
//     "    ggsize(height = 300, width = 500)\n",
//     "\n",
//     "basePlot\n"
//    ]
//   },
//   {
//    "cell_type": "code",
//    "execution_count": 5,
//    "id": "ecf71c0d",
//    "metadata": {},
//    "outputs": [
//     {
//      "data": {
//       "text/html": [
//        "   <div id=\"g6GUmJ\" ></div>\n",
//        "   <script type=\"text/javascript\" data-lets-plot-script=\"plot\">\n",
//        "   \n",
//        "   (function() {\n",
//        "   // ----------\n",
//        "   \n",
//        "   const forceImmediateRender = false;\n",
//        "   const responsive = false;\n",
//        "   \n",
//        "   let sizing = {\n",
//        "       width_mode: \"MIN\",\n",
//        "       height_mode: \"SCALED\",\n",
//        "       width: null, \n",
//        "       height: null \n",
//        "   };\n",
//        "   \n",
//        "   const preferredWidth = document.body.dataset.letsPlotPreferredWidth;\n",
//        "   if (preferredWidth !== undefined) {\n",
//        "       sizing = {\n",
//        "           width_mode: 'FIXED',\n",
//        "           height_mode: 'SCALED',\n",
//        "           width: parseFloat(preferredWidth)\n",
//        "       };\n",
//        "   }\n",
//        "   \n",
//        "   const containerDiv = document.getElementById(\"g6GUmJ\");\n",
//        "   let fig = null;\n",
//        "   \n",
//        "   function renderPlot() {\n",
//        "       if (fig === null) {\n",
//        "           const plotSpec = {\n",
//        "\"ggtitle\":{\n",
//        "\"text\":\"Natural strip text direction\"\n",
//        "},\n",
//        "\"mapping\":{\n",
//        "\"x\":\"mpg\",\n",
//        "\"y\":\"wt\"\n",
//        "},\n",
//        "\"data\":{\n",
//        "\"mpg\":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,16.4],\n",
//        "\"cyl\":[\"6\",\"6\",\"4\",\"6\",\"8\",\"6\",\"8\",\"4\",\"4\",\"6\",\"6\",\"8\"],\n",
//        "\"wt\":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,4.07]\n",
//        "},\n",
//        "\"ggsize\":{\n",
//        "\"width\":500.0,\n",
//        "\"height\":300.0\n",
//        "},\n",
//        "\"kind\":\"plot\",\n",
//        "\"scales\":[],\n",
//        "\"layers\":[{\n",
//        "\"mapping\":{\n",
//        "},\n",
//        "\"stat\":\"identity\",\n",
//        "\"color\":\"steelblue\",\n",
//        "\"position\":\"identity\",\n",
//        "\"geom\":\"point\",\n",
//        "\"data\":{\n",
//        "}\n",
//        "}],\n",
//        "\"theme\":{\n",
//        "\"name\":\"bw\",\n",
//        "\"strip_background_y\":{\n",
//        "\"fill\":\"aliceblue\",\n",
//        "\"color\":\"steelblue\",\n",
//        "\"blank\":false\n",
//        "},\n",
//        "\"panel_border\":{\n",
//        "\"color\":\"gray20\",\n",
//        "\"blank\":false\n",
//        "},\n",
//        "\"strip_text_y\":{\n",
//        "\"color\":\"darkblue / 0.4\",\n",
//        "\"face\":\"bold\",\n",
//        "\"size\":24.0,\n",
//        "\"angle\":0.0,\n",
//        "\"blank\":false\n",
//        "}\n",
//        "},\n",
//        "\"facet\":{\n",
//        "\"name\":\"grid\",\n",
//        "\"y\":\"cyl\",\n",
//        "\"x_order\":1.0,\n",
//        "\"y_order\":1.0\n",
//        "},\n",
//        "\"data_meta\":{\n",
//        "\"series_annotations\":[{\n",
//        "\"type\":\"float\",\n",
//        "\"column\":\"mpg\"\n",
//        "},{\n",
//        "\"type\":\"float\",\n",
//        "\"column\":\"wt\"\n",
//        "},{\n",
//        "\"type\":\"str\",\n",
//        "\"column\":\"cyl\"\n",
//        "}]\n",
//        "},\n",
//        "\"spec_id\":\"3\"\n",
//        "};\n",
//        "           window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });\n",
//        "       } else {\n",
//        "           fig.updateView({});\n",
//        "       }\n",
//        "   }\n",
//        "   \n",
//        "   const renderImmediately = \n",
//        "       forceImmediateRender || (\n",
//        "           sizing.width_mode === 'FIXED' && \n",
//        "           (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')\n",
//        "       );\n",
//        "   \n",
//        "   if (renderImmediately) {\n",
//        "       renderPlot();\n",
//        "   }\n",
//        "   \n",
//        "   if (!renderImmediately || responsive) {\n",
//        "       // Set up observer for initial sizing or continuous monitoring\n",
//        "       var observer = new ResizeObserver(function(entries) {\n",
//        "           for (let entry of entries) {\n",
//        "               if (entry.contentBoxSize && \n",
//        "                   entry.contentBoxSize[0].inlineSize > 0) {\n",
//        "                   if (!responsive && observer) {\n",
//        "                       observer.disconnect();\n",
//        "                       observer = null;\n",
//        "                   }\n",
//        "                   renderPlot();\n",
//        "                   if (!responsive) {\n",
//        "                       break;\n",
//        "                   }\n",
//        "               }\n",
//        "           }\n",
//        "       });\n",
//        "       \n",
//        "       observer.observe(containerDiv);\n",
//        "   }\n",
//        "   \n",
//        "   // ----------\n",
//        "   })();\n",
//        "   \n",
//        "   </script>                <svg xmlns=\"http://www.w3.org/2000/svg\" xmlns:xlink=\"http://www.w3.org/1999/xlink\" display=\"block\" class=\"plt-container\" id=f2b4a40b-9f19-4a27-b292-228339c3a01e width=\"100%\" height=\"100%\" style=\"max-width: 500.0px; max-height: 300.0px;\" viewBox=\"0 0 500.0 300.0\" preserveAspectRatio=\"xMinYMin meet\">\n",
//        "  <style type=\"text/css\">\n",
//        "  .plt-container {\n",
//        "   font-family: sans-serif;\n",
//        "   user-select: none;\n",
//        "   -webkit-user-select: none;\n",
//        "   -moz-user-select: none;\n",
//        "   -ms-user-select: none;\n",
//        "}\n",
//        "text {\n",
//        "   text-rendering: optimizeLegibility;\n",
//        "}\n",
//        "#pneyCCN .plot-title {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 16.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .plot-subtitle {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 15.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .plot-caption {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .plot-tag {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 16.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .hyperlink-element {\n",
//        "fill:#118ed8;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .legend-title {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 15.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .legend-item {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .axis-title-x {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 15.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .axis-text-x {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#dMdJZaM .axis-tooltip-text-x {\n",
//        "fill:#ffffff;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .axis-title-y {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 15.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .axis-text-y {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#dMdJZaM .axis-tooltip-text-y {\n",
//        "fill:#ffffff;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .facet-strip-text-x {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#pneyCCN .facet-strip-text-y {\n",
//        "fill:#00008b;\n",
//        "fill-opacity:0.4;\n",
//        "font-weight: bold;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 24.0px;\n",
//        "\n",
//        "}\n",
//        "#dMdJZaM .tooltip-text {\n",
//        "fill:#474747;\n",
//        "font-weight: normal;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#dMdJZaM .tooltip-title {\n",
//        "fill:#474747;\n",
//        "font-weight: bold;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "#dMdJZaM .tooltip-label {\n",
//        "fill:#474747;\n",
//        "font-weight: bold;\n",
//        "font-style: normal;\n",
//        "font-family: sans-serif;\n",
//        "font-size: 13.0px;\n",
//        "\n",
//        "}\n",
//        "\n",
//        "  </style>\n",
//        "  <g id=\"pneyCCN\">\n",
//        "    <path fill-rule=\"evenodd\" fill=\"rgb(255,255,255)\" fill-opacity=\"1.0\" d=\"M0.0 0.0 L0.0 300.0 L500.0 300.0 L500.0 0.0 Z\">\n",
//        "    </path>\n",
//        "    <g transform=\"translate(21.0 22.0 ) \">\n",
//        "      <g>\n",
//        "        <rect x=\"13.980605455468202\" y=\"0.0\" height=\"72.66666666666667\" width=\"437.29481037315975\" fill=\"rgb(255,255,255)\" fill-opacity=\"1.0\">\n",
//        "        </rect>\n",
//        "        <g transform=\"translate(13.980605455468202 0.0 ) \">\n",
//        "          <g>\n",
//        "            <line x1=\"47.42936512148128\" y1=\"0.0\" x2=\"47.42936512148128\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"126.15030308244616\" y1=\"0.0\" x2=\"126.15030308244616\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"204.87124104341103\" y1=\"0.0\" x2=\"204.87124104341103\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"283.5921790043759\" y1=\"0.0\" x2=\"283.5921790043759\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"362.3131169653408\" y1=\"0.0\" x2=\"362.3131169653408\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"8.068896140998845\" y1=\"0.0\" x2=\"8.068896140998845\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"1.4\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"86.78983410196372\" y1=\"0.0\" x2=\"86.78983410196372\" y2=\"72.66666666666667\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"1.4\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\
" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"0.0\" y1=\"24.819913419913433\" x2=\"437.29481037315975\" y2=\"24.819913419913433\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"0.5\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"0.0\" y1=\"43.6943722943723\" x2=\"437.29481037315975\" y2=\"43.6943722943723\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"1.4\" fill=\"none\">\n",
//        "            </line>\n",
//        "            <line x1=\"0.0\" y1=\"5.945454545454567\" x2=\"437.29481037315975\" y2=\"5.945454545454567\" stroke=\"rgb(233,233,233)\" stroke-opacity=\"1.0\" stroke-width=\"1.4\" fill=\"none\">\n",
//        "            </line>\n",
//        "          </g>\n",
//        "        </g>\n",
//        "      </g>\n",
//        "      <g clip-path=\"url(#c8xkwlJ)\" clip-bounds-jfx=\"[rect (13.980605455468202, 165.33333333333334), (437.29481037315975, 72.66666666666667)]\">\n",
//        "        <g transform=\"translate(13.980605455468202 165.33333333333334 ) \">\n",
//        "          <g>\n",
//        "            <g buffered-rendering=\"static\">\n",
//        "              <g>\n",
//        "                <g >\n",
//        "                  <circle fill=\"#4682b4\" stroke=\"#000000\" stroke-opacity=\"0.0\" stroke-width=\"0.0\" cx=\"193.06310034926628\" cy=\"27.084848484848493\" r=\"3.3000000000000003\" />\n",
//        "                  <circle fill=\"#4682b4\" stroke=\"#000000\" stroke-opacity=\"0.0\" stroke-width=\"0.0\" cx=\"19.8770368351436\" cy=\"22.177489177489207\" r=\"3.3000000000000003\" />\n",
//        "                  <circle fill=\"#4682b4\" stroke=\"#000000\" stroke-opacity=\"0.0\" stroke-width=\"0.0\" cx=\"102.53402169415665\" cy=\"3.3030303030303116\" r=\"3.3000000000000003\" />\n",
//        "                </g>\n",
//        "              </g>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "        </g>\n",
//        "        <defs>\n",
//        "          <clipPath id=\"c8xkwlJ\">\n",
//        "            <rect x=\"13.980605455468202\" y=\"165.33333333333334\" width=\"437.29481037315975\" height=\"72.66666666666667\">\n",
//        "            </rect>\n",
//        "          </clipPath>\n",
//        "        </defs>\n",
//        "      </g>\n",
//        "      <g>\n",
//        "        <g transform=\"translate(13.980605455468202 238.0 ) \">\n",
//        "          <g transform=\"translate(8.068896140998845 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>14</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(86.78983410196372 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>16</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(165.5107720629286 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>18</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(244.23171002389347 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>20</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(322.95264798485834 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>22</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(401.6735859458232 0.0 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"0.0\" y2=\"4.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(0.0 6.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-x\" text-anchor=\"middle\" dy=\"0.7em\">\n",
//        "                <tspan>24</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "        </g>\n",
//        "        <g transform=\"translate(13.980605455468202 165.33333333333334 ) \">\n",
//        "          <g transform=\"translate(0.0 43.6943722943723 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"-4.0\" y2=\"0.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(-6.0 0.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-y\" text-anchor=\"end\" dy=\"0.35em\">\n",
//        "                <tspan>3</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "          <g transform=\"translate(0.0 5.945454545454567 ) \">\n",
//        "            <line stroke-width=\"1.0\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" x2=\"-4.0\" y2=\"0.0\">\n",
//        "            </line>\n",
//        "            <g transform=\"translate(-6.0 0.0 ) \">\n",
//        "              <text style=\"font-size:13.0px;\" y=\"0.0\" class=\"axis-text-y\" text-anchor=\"end\" dy=\"0.35em\">\n",
//        "                <tspan>4</tspan>\n",
//        "              </text>\n",
//        "            </g>\n",
//        "          </g>\n",
//        "        </g>\n",
//        "        <rect x=\"13.980605455468202\" y=\"165.33333333333334\" height=\"72.66666666666667\" width=\"437.29481037315975\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" stroke-width=\"1.0\" fill-opacity=\"0.0\">\n",
//        "        </rect>\n",
//        "        <rect x=\"13.980605455468202\" y=\"165.33333333333334\" height=\"72.66666666666667\" width=\"437.29481037315975\" stroke=\"rgb(51,51,51)\" stroke-opacity=\"1.0\" stroke-width=\"1.0\" fill-opacity=\"0.0\">\n",
//        "        </rect>\n",
//        "      </g>\n",
//        "      <rect x=\"451.27541582862796\" y=\"165.33333333333334\" height=\"72.66666666666667\" width=\"21.724584171372037\" stroke-width=\"1.0\" fill=\"rgb(240,248,255)\" fill-opacity=\"1.0\" stroke=\"rgb(70,130,180)\" stroke-opacity=\"1.0\">\n",
//        "      </rect>\n",
//        "      <g transform=\"translate(462.137707914314 208.86666666666667 ) \">\n",
//        "        <text style=\"font-size:24.0px;\" y=\"0.0\" class=\"facet-strip-text-y\" text-anchor=\"middle\">\n",
//        "          <tspan>8</tspan>\n",
//        "        </text>\n",
//        "      </g>\n",
//        "    </g>\n",
//        "    <g transform=\"translate(34.9806054554682 15.8 ) \">\n",
//        "      <text style=\"font-size:16.0px;\" y=\"0.0\" class=\"plot-title\">\n",
//        "        <tspan>Natural strip text direction</tspan>\n",
//        "      </text>\n",
//        "    </g>\n",
//        "    <g transform=\"translate(15.0 141.0 ) rotate(-90.0 ) \">\n",
//        "      <text style=\"font-size:15.0px;\" y=\"0.0\" class=\"axis-title-y\" text-anchor=\"middle\">\n",
//        "        <tspan>wt</tspan>\n",
//        "      </text>\n",
//        "    </g>\n",
//        "    <g transform=\"translate(253.62801064204808 294.0 ) \">\n",
//        "      <text style=\"font-size:15.0px;\" y=\"0.0\" class=\"axis-title-x\" text-anchor=\"middle\">\n",
//        "        <tspan>mpg</tspan>\n",
//        "      </text>\n",
//        "    </g>\n",
//        "    <path fill=\"rgb(0,0,0)\" fill-opacity=\"0.0\" stroke=\"rgb(71,71,71)\" stroke-opacity=\"1.0\" stroke-width=\"0.0\" d=\"M0.0 0.0 L0.0 300.0 L500.0 300.0 L500.0 0.0 Z\" pointer-events=\"none\">\n",
//        "    </path>\n",
//        "  </g>\n",
//        "  <g id=\"dMdJZaM\">\n",
//        "  </g>\n",
//        "</svg>\n",
//        "                <script>document.getElementById(\"f2b4a40b-9f19-4a27-b292-228339c3a01e\").style.display = \"none\";</script>"
//       ]
//      },
//      "execution_count": 5,
//      "metadata": {},
//      "output_type": "execute_result"
//     }
//    ],
//    "source": [
//     "basePlot +\n",
//     "    theme(\n",
//     "        stripTextY = elementText(\n",
//     "            angle = 0,\n",
//     "            size = 24,\n",
//     "            face = \"bold\",\n",
//     "            color = \"darkblue / 0.4\"\n",
//     "        )\n",
//     "    ) +\n",
//     "    ggtitle(\"Natural strip text direction\")\n"
//    ]
//   },
//   {
//    "cell_type": "markdown",
//    "id": "8cd27159",
//    "metadata": {},
//    "source": [
//     "## Rotating Horizontal and Vertical Strip Labels\n"
//    ]
//   },
//   {
//    "cell_type": "code",
//    "execution_count": 6,
//    "id": "22bb8116",
//    "metadata": {},
//    "outputs": [
//     {
//      "data": {
//       "text/html": [
//        "   <div id=\"1DFJzB\" ></div>\n",
//        "   <script type=\"text/javascript\" data-lets-plot-script=\"plot\">\n",
//        "   \n",
//        "   (function() {\n",
//        "   // ----------\n",
//        "   \n",
//        "   const forceImmediateRender = false;\n",
//        "   const responsive = false;\n",
//        "   \n",
//        "   let sizing = {\n",
//        "       width_mode: \"MIN\",\n",
//        "       height_mode: \"SCALED\",\n",
//        "       width: null, \n",
//        "       height: null \n",
//        "   };\n",
//        "   \n",
//        "   const preferredWidth = document.body.dataset.letsPlotPreferredWidth;\n",
//        "   if (preferredWidth !== undefined) {\n",
//        "       sizing = {\n",
//        "           width_mode: 'FIXED',\n",
//        "           height_mode: 'SCALED',\n",
//        "           width: parseFloat(preferredWidth)\n",
//        "       };\n",
//        "   }\n",
//        "   \n",
//        "   const containerDiv = document.getElementById(\"1DFJzB\");\n",
//        "   let fig = null;\n",
//        "   \n",
//        "   function renderPlot() {\n",
//        "       if (fig === null) {\n",
//        "           const plotSpec = {\n",
//        "\"ggtitle\":{\n",
//        "\"text\":\"Custom angles for facet strip labels\"\n",
//        "},\n",
//        "\"mapping\":{\n",
//        "\"x\":\"quarter\",\n",
//        "\"y\":\"value\"\n",
//        "},\n",
//        "\"data\":{\n",
//        "\"segment\":[\"Retail\",\"Retail\",\"Retail\",\"Retail\",\"Online\",\"Online\",\"Online\",\"Online\"],\n",
//        "\"region\":[\"North\",\"North\",\"South\",\"South\",\"North\",\"North\",\"South\",\"South\"],\n",
//        "\"value\":[12.0,15.0,9.0,11.0,16.0,18.0,13.0,17.0],\n",
//        "\"quarter\":[\"Q1\",\"Q2\",\"Q1\",\"Q2\",\"Q1\",\"Q2\",\"Q1\",\"Q2\"]\n",
//        "},\n",
//        "\"ggsize\":{\n",
//        "\"width\":700.0,\n",
//        "\"height\":420.0\n",
//        "},\n",
//        "\"kind\":\"plot\",\n",
//        "\"scales\":[],\n",
//        "\"layers\":[{\n",
//        "\"mapping\":{\n",
//        "},\n",
//        "\"stat\":\"identity\",\n",
//        "\"color\":\"white\",\n",
//        "\"position\":\"stack\",\n",
//        "\"geom\":\"bar\",\n",
//        "\"fill\":\"steelblue\",\n",
//        "\"data\":{\n",
//        "}\n",
//        "}],\n",
//        "\"theme\":{\n",
//        "\"name\":\"bw\",\n",
//        "\"strip_background_y\":{\n",
//        "\"fill\":\"lemonchiffon\",\n",
//        "\"color\":\"tan\",\n",
//        "\"blank\":false\n",
//        "},\n",
//        "\"strip_text_x\":{\n",
//        "\"color\":\"steelblue\",\n",
//        "\"face\":\"bold\",\n",
//        "\"size\":13.0,\n",
//        "\"angle\":35.0,\n",
//        "\"blank\":false\n",
//        "},\n",
//        "\"strip_background_x\":{\n",
//        "\"fill\":\"aliceblue\",\n",
//        "\"color\":\"cadetblue\",\n",
//        "\"blank\":false\n",
//        "},\n",
//        "\"strip_text_y\":{\n",
//        "\"color\":\"salmon\",\n",
//        "\"face\":\"bold\",\n",
//        "\"size\":13.0,\n",
//        "\"angle\":35.0,\n",
//        "\"blank\":false\n",
//        "}\n",
//        "},\n",
//        "\
) rotate(-90.0 ) \">\n",
//        "      <text style=\"font-size:15.0px;\" y=\"0.0\" class=\"axis-title-y\" text-anchor=\"middle\">\n",
//        "        <tspan>value</tspan>\n",
//        "      </text>\n",
//        "    </g>\n",
//        "    <g transform=\"translate(341.8160236337623 414.0 ) \">\n",
//        "      <text style=\"font-size:15.0px;\" y=\"0.0\" class=\"axis-title-x\" text-anchor=\"middle\">\n",
//        "        <tspan>quarter</tspan>\n",
//        "      </text>\n",
//        "    </g>\n",
//        "    <path fill=\"rgb(0,0,0)\" fill-opacity=\"0.0\" stroke=\"rgb(71,71,71)\" stroke-opacity=\"1.0\" stroke-width=\"0.0\" d=\"M0.0 0.0 L0.0 420.0 L700.0 420.0 L700.0 0.0 Z\" pointer-events=\"none\">\n",
//        "    </path>\n",
//        "  </g>\n",
//        "  <g id=\"dALhQDZ\">\n",
//        "  </g>\n",
//        "</svg>\n",
//        "                <script>document.getElementById(\"feb70900-b65d-4178-897e-c1b088272dde\").style.display = \"none\";</script>"
//       ]
//      },
//      "execution_count": 6,
//      "metadata": {},
//      "output_type": "execute_result"
//     }
//    ],
//    "source": [
//     "val sales = mapOf(\n",
//     "    \"region\" to listOf(\"North\", \"North\", \"South\", \"South\", \"North\", \"North\", \"South\", \"South\"),\n",
//     "    \"segment\" to listOf(\"Retail\", \"Retail\", \"Retail\", \"Retail\", \"Online\", \"Online\", \"Online\", \"Online\"),\n",
//     "    \"quarter\" to listOf(\"Q1\", \"Q2\", \"Q1\", \"Q2\", \"Q1\", \"Q2\", \"Q1\", \"Q2\"),\n",
//     "    \"value\" to listOf(12, 15, 9, 11, 16, 18, 13, 17)\n",
//     ")\n",
//     "\n",
//     "letsPlot(sales) { x = \"quarter\"; y = \"value\" } +\n",
//     "    geomBar(stat = Stat.identity, fill = \"steelblue\", color = \"white\") +\n",
//     "    facetGrid(x = \"region\", y = \"segment\") +\n",
//     "    themeBW() +\n",
//     "    theme(\n",
//     "        stripTextX = elementText(angle = 35, size = 13, face = \"bold\", color = \"steelblue\"),\n",
//     "        stripTextY = elementText(angle = 35, size = 13, face = \"bold\", color = \"salmon\"),\n",
//     "        stripBackgroundX = elementRect(fill = \"aliceblue\", color = \"cadetblue\"),\n",
//     "        stripBackgroundY = elementRect(fill = \"lemonchiffon\", color = \"tan\")\n",
//     "    ) +\n",
//     "    ggsize(700, 420) +\n",
//     "    ggtitle(\"Custom angles for facet strip labels\")\n"
//    ]
//   }
//  ],
//  "metadata": {
//   "kernelspec": {
//    "display_name": "Kotlin",
//    "language": "kotlin",
//    "name": "kotlin"
//   },
//   "language_info": {
//    "codemirror_mode": "text/x-kotlin",
//    "file_extension": ".kt",
//    "mimetype": "text/x-kotlin",
//    "name": "kotlin",
//    "nbconvert_exporter": "",
//    "pygments_lexer": "kotlin",
//    "version": "2.4.0-dev-6891"
//   }
//  },
//  "nbformat": 4,
//  "nbformat_minor": 5
// }

// %%
LetsPlot.getInfo()

// %% [markdown]
// ## Horizontal Y-Axis Strip Labels
//
// By default, y-axis strip labels are vertical. When the labels are short, it may be more convenient to display them horizontally.

// %%
basePlot +
    theme(
        stripTextY = elementText(
            angle = 0,
            size = 24,
            face = "bold",
            color = "darkblue / 0.4"
        )
    ) +
    ggtitle("Natural strip text direction")

// %%
val sales = mapOf(
    "region" to listOf("North", "North", "South", "South", "North", "North", "South", "South"),
    "segment" to listOf("Retail", "Retail", "Retail", "Retail", "Online", "Online", "Online", "Online"),
    "quarter" to listOf("Q1", "Q2", "Q1", "Q2", "Q1", "Q2", "Q1", "Q2"),
    "value" to listOf(12, 15, 9, 11, 16, 18, 13, 17)
)

letsPlot(sales) { x = "quarter"; y = "value" } +
    geomBar(stat = Stat.identity, fill = "steelblue", color = "white") +
    facetGrid(x = "region", y = "segment") +
    themeBW() +
    theme(
        stripTextX = elementText(angle = 35, size = 13, face = "bold", color = "steelblue"),
        stripTextY = elementText(angle = 35, size = 13, face = "bold", color = "salmon"),
        stripBackgroundX = elementRect(fill = "aliceblue", color = "cadetblue"),
        stripBackgroundY = elementRect(fill = "lemonchiffon", color = "tan")
    ) +
    ggsize(700, 420) +
    ggtitle("Custom angles for facet strip labels")
