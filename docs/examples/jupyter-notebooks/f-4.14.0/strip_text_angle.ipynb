// %% [markdown]
// # Facet Strip Text Angle
//
// Facet strip labels can be rotated with the `angle` parameter in `elementText()`. Use `stripTextX` for horizontal facet labels and `stripTextY` for vertical facet labels. Use `stripText` to change both.

// %%
%use lets-plot
// Out:
//    <div id="rp9UYF"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.10.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("rp9UYF").appendChild(div);
//            };
//            var e = document.getElementById("rp9UYF");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.10.1/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.14.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.10.1.
// Outputs: Web (HTML+JS), Static SVG (hidden)

// %%
val mtcars = mapOf(
    "mpg" to listOf(21.0, 21.0, 22.8, 21.4, 18.7, 18.1, 14.3, 24.4, 22.8, 19.2, 17.8, 16.4),
    "wt" to listOf(2.620, 2.875, 2.320, 3.215, 3.440, 3.460, 3.570, 3.190, 3.150, 3.440, 3.440, 4.070),
    "cyl" to listOf("6", "6", "4", "6", "8", "6", "8", "4", "4", "6", "6", "8")
)

// %% [markdown]
// ## Horizontal Y-Axis Strip Labels
//
// By default, y-axis strip labels are vertical. When the labels are short, it may be more convenient to display them horizontally.

// %%
val basePlot = letsPlot(mtcars) { x = "mpg"; y = "wt" } +
    geomPoint(color = "steelblue") +
    facetGrid(y = "cyl") +
    themeBW() +
    theme(
        panelBorder = elementRect(color = "gray20"),
        stripBackgroundY = elementRect(fill = "aliceblue", color = "steelblue")
    ) +
    ggtitle("Default strip label appearance") +
    ggsize(height = 300, width = 500)

basePlot
// Out:
//    <div id="wBrwUX"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.10.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("wBrwUX").appendChild(div);
//            };
//            var e = document.getElementById("wBrwUX");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="MvnVqm" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("MvnVqm");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "ggtitle":{
// "text":"Default strip label appearance"
// },
// "mapping":{
// "x":"mpg",
// "y":"wt"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,16.4],
// "cyl":["6","6","4","6","8","6","8","4","4","6","6","8"],
// "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,4.07]
// },
// "ggsize":{
// "width":500.0,
// "height":300.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"steelblue",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "strip_background_y":{
// "fill":"aliceblue",
// "color":"steelblue",
// "blank":false
// },
// "panel_border":{
// "color":"gray20",
// "blank":false
// }
// },
// "facet":{
// "name":"grid",
// "y":"cyl",
// "x_order":1.0,
// "y_order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"float",
// "column":"mpg"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"str",
// "column":"cyl"
// }]
// },
// "spec_id":"1"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=2392e137-2166-4490-a508-8ed434251a5e width="100%" height="100%" style="max-width: 500.0px; max-height: 300.0px;" viewBox="0 0 500.0 300.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p3XdwAe .plot-title {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #p3XdwAe .plot-subtitle {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p3XdwAe .plot-caption {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p3XdwAe .plot-tag {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #p3XdwAe .hyperlink-element {
// fill:#118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #p3XdwAe .legend-title {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p3XdwAe .legend-item {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p3XdwAe .axis-title-x {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p3XdwAe .axis-text-x {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dOrfvUW .axis-tooltip-text-x {
// fill:#ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p3XdwAe .axis-title-y {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p3XdwAe .axis-text-y {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dOrfvUW .axis-tooltip-text-y {
// fill:#ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p3XdwAe .facet-strip-text-x {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p3XdwAe .facet-strip-text-y {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dOrfvUW .tooltip-text {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dOrfvUW .tooltip-title {
// fill:#474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dOrfvUW .tooltip-label {
// fill:#474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="p3XdwAe">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 300.0 L500.0 300.0 L500.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 22.0 ) ">
//       <g>
//         <rect x="13.980605455468202" y="0.0" height="72.66666666666667" width="440.0193945445318" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(13.980605455468202 0.0 ) ">
//           <g>
//             <line x1="47.72487582593703" y1="0.0" x2="47.72487582593703" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="126.93628798516875" y1="0.0" x2="126.93628798516875" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="206.14770014440035" y1="0.0" x2="206.14770014440035" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="285.35911230363206" y1="0.0" x2="285.35911230363206" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="364.5705244628638" y1="0.0" x2="364.5705244628638" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="8.119169746321177" y1="0.0" x2="8.119169746321177" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="87.33058190555289" y1="0.0" x2="87.33058190555289" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="166.5419940647846" y1="0.0" x2="166.5419940647846" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="245.7534062240162" y1="0.0" x2="245.7534062240162" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="324.9648183832479" y1="0.0" x2="324.9648183832479" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" f

// %%
basePlot +
    theme(
        stripTextY = elementText(
            angle = 0,
            size = 24,
            face = "bold",
            color = "darkblue / 0.4"
        )
    ) +
    ggtitle("Natural strip text direction")
// Out:
//    <div id="ZpwwVp" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("ZpwwVp");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "ggtitle":{
// "text":"Natural strip text direction"
// },
// "mapping":{
// "x":"mpg",
// "y":"wt"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,16.4],
// "cyl":["6","6","4","6","8","6","8","4","4","6","6","8"],
// "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,4.07]
// },
// "ggsize":{
// "width":500.0,
// "height":300.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"steelblue",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "strip_background_y":{
// "fill":"aliceblue",
// "color":"steelblue",
// "blank":false
// },
// "panel_border":{
// "color":"gray20",
// "blank":false
// },
// "strip_text_y":{
// "color":"darkblue / 0.4",
// "face":"bold",
// "size":24.0,
// "angle":0.0,
// "blank":false
// }
// },
// "facet":{
// "name":"grid",
// "y":"cyl",
// "x_order":1.0,
// "y_order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"float",
// "column":"mpg"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"str",
// "column":"cyl"
// }]
// },
// "spec_id":"3"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=d8075df0-0536-4a78-ade4-a737a70e125c width="100%" height="100%" style="max-width: 500.0px; max-height: 300.0px;" viewBox="0 0 500.0 300.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pWLUTbx .plot-title {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pWLUTbx .plot-subtitle {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pWLUTbx .plot-caption {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pWLUTbx .plot-tag {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pWLUTbx .hyperlink-element {
// fill:#118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pWLUTbx .legend-title {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pWLUTbx .legend-item {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pWLUTbx .axis-title-x {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pWLUTbx .axis-text-x {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dbbJwZk .axis-tooltip-text-x {
// fill:#ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pWLUTbx .axis-title-y {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pWLUTbx .axis-text-y {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dbbJwZk .axis-tooltip-text-y {
// fill:#ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pWLUTbx .facet-strip-text-x {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pWLUTbx .facet-strip-text-y {
// fill:#00008b;
// fill-opacity:0.4;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 24.0px;
//
// }
// #dbbJwZk .tooltip-text {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dbbJwZk .tooltip-title {
// fill:#474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dbbJwZk .tooltip-label {
// fill:#474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pWLUTbx">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 300.0 L500.0 300.0 L500.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 22.0 ) ">
//       <g>
//         <rect x="13.980605455468202" y="0.0" height="72.66666666666667" width="437.29481037315975" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(13.980605455468202 0.0 ) ">
//           <g>
//             <line x1="47.42936512148128" y1="0.0" x2="47.42936512148128" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="126.15030308244616" y1="0.0" x2="126.15030308244616" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="204.87124104341103" y1="0.0" x2="204.87124104341103" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="283.5921790043759" y1="0.0" x2="283.5921790043759" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="362.3131169653408" y1="0.0" x2="362.3131169653408" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="8.068896140998845" y1="0.0" x2="8.068896140998845" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="86.78983410196372" y1="0.0" x2="86.78983410196372" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="165.5107720629286" y1="0.0" x2="165.5107720629286" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="244.23171002389347" y1="0.0" x2="244.23171002389347" y2="72.66666666666667" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="322.95264798485834" y1="0

// %% [markdown]
// ## Rotating Horizontal and Vertical Strip Labels

// %%
val sales = mapOf(
    "region" to listOf("North", "North", "South", "South", "North", "North", "South", "South"),
    "segment" to listOf("Retail", "Retail", "Retail", "Retail", "Online", "Online", "Online", "Online"),
    "quarter" to listOf("Q1", "Q2", "Q1", "Q2", "Q1", "Q2", "Q1", "Q2"),
    "value" to listOf(12, 15, 9, 11, 16, 18, 13, 17)
)

letsPlot(sales) { x = "quarter"; y = "value" } +
    geomBar(stat = Stat.identity, fill = "steelblue", color = "white") +
    facetGrid(x = "region", y = "segment") +
    themeBW() +
    theme(
        stripTextX = elementText(angle = 35, size = 13, face = "bold", color = "steelblue"),
        stripTextY = elementText(angle = 35, size = 13, face = "bold", color = "salmon"),
        stripBackgroundX = elementRect(fill = "aliceblue", color = "cadetblue"),
        stripBackgroundY = elementRect(fill = "lemonchiffon", color = "tan")
    ) +
    ggsize(700, 420) +
    ggtitle("Custom angles for facet strip labels")
// Out:
//    <div id="XRs52K" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("XRs52K");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "ggtitle":{
// "text":"Custom angles for facet strip labels"
// },
// "mapping":{
// "x":"quarter",
// "y":"value"
// },
// "data":{
// "segment":["Retail","Retail","Retail","Retail","Online","Online","Online","Online"],
// "region":["North","North","South","South","North","North","South","South"],
// "value":[12.0,15.0,9.0,11.0,16.0,18.0,13.0,17.0],
// "quarter":["Q1","Q2","Q1","Q2","Q1","Q2","Q1","Q2"]
// },
// "ggsize":{
// "width":700.0,
// "height":420.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"white",
// "position":"stack",
// "geom":"bar",
// "fill":"steelblue",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "strip_background_y":{
// "fill":"lemonchiffon",
// "color":"tan",
// "blank":false
// },
// "strip_text_x":{
// "color":"steelblue",
// "face":"bold",
// "size":13.0,
// "angle":35.0,
// "blank":false
// },
// "strip_background_x":{
// "fill":"aliceblue",
// "color":"cadetblue",
// "blank":false
// },
// "strip_text_y":{
// "color":"salmon",
// "face":"bold",
// "size":13.0,
// "angle":35.0,
// "blank":false
// }
// },
// "facet":{
// "name":"grid",
// "x":"region",
// "y":"segment",
// "x_order":1.0,
// "y_order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"region"
// },{
// "type":"str",
// "column":"segment"
// },{
// "type":"str",
// "column":"quarter"
// },{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"5"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=9e0050f3-d225-4ece-a78c-cfaacd0f8883 width="100%" height="100%" style="max-width: 700.0px; max-height: 420.0px;" viewBox="0 0 700.0 420.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pNo5i5f .plot-title {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pNo5i5f .plot-subtitle {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pNo5i5f .plot-caption {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pNo5i5f .plot-tag {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pNo5i5f .hyperlink-element {
// fill:#118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pNo5i5f .legend-title {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pNo5i5f .legend-item {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pNo5i5f .axis-title-x {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pNo5i5f .axis-text-x {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dI9goFW .axis-tooltip-text-x {
// fill:#ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pNo5i5f .axis-title-y {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pNo5i5f .axis-text-y {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dI9goFW .axis-tooltip-text-y {
// fill:#ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pNo5i5f .facet-strip-text-x {
// fill:#4682b4;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pNo5i5f .facet-strip-text-y {
// fill:#fa8072;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dI9goFW .tooltip-text {
// fill:#474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dI9goFW .tooltip-title {
// fill:#474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dI9goFW .tooltip-label {
// fill:#474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pNo5i5f">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 420.0 L700.0 420.0 L700.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 22.0 ) ">
//       <g>
//         <rect x="21.961210910936405" y="40.47950401710497" height="153.7602479914475" width="293.8548127228259" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(21.961210910936405 40.47950401710497 ) ">
//           <g>
//             <line x1="19.164444308010395" y1="0.0" x2="19.164444308010395" y2="153.7602479914475" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="146.92740636141298" y1="0.0" x2="146.92740636141298" y2="153.7602479914475" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="274.69036841481557" y1="0.0" x2="274.69036841481557" y2="153.7602479914475" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="83.04592533471168" y1="0.0" x2="83.04592533471168" y2="153.7602479914475" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="210.80888738811427" y1="0.0" x2="210.80888738811427" y2="153.7602479914475" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(21.961210910936405 40.47950401710497 ) ">
//           <g>
//             <line x1="0.0" y1="133.42159084972164" x2="293.8548127228259" y2="133.42159084972164" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="0.0" y1="92.74427656626992" x2="293.8548127228259" y2="92.74427656626992" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="0.0" y1="52.06696
