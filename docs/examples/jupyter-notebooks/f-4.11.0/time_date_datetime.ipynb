// %% [markdown]
// # Plotting Time Series
//
// Lets-Plot handles all temporal data types through a unified "datetime" scale (excluding duration, which is handled by the "time" scale). <br>
// This is in contrast to R's ggplot2, which provides separate "date", "time", and "datetime" scales.
//
// **Supported temporal data types:**
//
// **kotlinx.datetime** library:
//
// - `Instant`
// - `LocalDate`
// - `LocalTime`
// - `LocalDateTime`
//
// **java.time** package:
//
// - `Instant`
// - `LocalDate`
// - `LocalTime`
// - `LocalDateTime`
// - `ZonedDateTime` (timezone-aware)
// - `OffsetDateTime` (timezone-aware with offset)
//
// **java.util** package:
//
// - `Date`

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="zrTBAm"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("zrTBAm").appendChild(div);
//            };
//            var e = document.getElementById("zrTBAm");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.0.0.0-SNAPSHOT. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.7.0.

// %%
import kotlin.math.*

fun squiggle(x: Double): Double {
    return sin(3 * x) / (x * (cos(x) + 2))
}

// %%
val N = 50
val xs = (0 until N).map { i -> 1.0 + (25.0 - 1.0) * i / (N - 1) }
val ys = xs.map { squiggle(it) }

// %% [markdown]
// #### Local Time
//
// `kotlinx.datetime.LocalTime` and `java.time.LocalTime` represent time-of-day values (local/clock time) independent of any specific date.
//
// The `datetime` scale renders these with default tooltips and scale breaks optimized for hours or smaller time units.

// %%
import kotlinx.datetime.LocalTime

// Create time objects at regular intervals: every 12 minutes starting from 8:00 AM
val startTime = LocalTime(8, 0)  // 8:00 AM
val intervalMinutes = 12
val xsTime = (0 until N).map { i ->
    val totalMinutes = i * intervalMinutes
    val hours = 8 + totalMinutes / 60
    val minutes = totalMinutes % 60
    LocalTime(hours, minutes)
}

val data = mapOf(
    "xs" to xsTime,
    "ys" to ys
)

(letsPlot(data = data) { x = "xs"; y = "ys" } +
    geomBand(
        xmin = LocalTime(12, 30),        // <-- Use a compatible datatype ('LocalTime' here) for a constant value.
        xmax = LocalTime(13, 30),
        tooltips = layerTooltips()
            .title("Lunch Time")
            .line("^xmin - ^xmax")
            .line("in any time zone")
    ) +
    geomLine(
        tooltips = layerTooltips()
            .line("Time:|@xs")
            .format("^x", "%H:%M:%S"),
        color = "#1380A1", 
        size = 2
    ) +
    ggtb() + 
    ggsize(800, 400) + 
    theme(axisTitle = "blank")
)
// Out:
//    <div id="rHQr26"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("rHQr26").appendChild(div);
//            };
//            var e = document.getElementById("rHQr26");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="YvyFs3"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("YvyFs3");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"xs",
// "y":"ys"
// },
// "data":{
// "ys":[0.05555244654696321,-0.31308975753180435,-0.10643462133932577,0.30009232333113145,0.17296312035336703,-0.22071111372232088,-0.13299780037831993,0.08650221374128016,0.07517308831149005,-0.03457732712883878,-0.053011702893076613,0.01613253296393087,0.05025135841149322,-0.006087168607620953,-0.06373424084254278,-0.007203131933992198,0.09508414134219141,0.030997473081211188,-0.08736932916274698,-0.03395485486461525,0.042462211485356505,0.02498071850034842,-0.021846761376655595,-0.021667111013930086,0.014102019771655625,0.02429063240307002,-0.010820138233714487,-0.03549936052176265,0.0074705086233501,0.05839869912786762,0.002691520004471486,-0.055042584594207355,-0.010168953244153327,0.02907608751881987,0.010370233132486369,-0.01702935417966255,-0.010922022515953079,0.012888239469640033,0.014111413375350355,-0.01242410772629795,-0.02311035299814162,0.013738836902986275,0.040600698558063315,-0.009436090766507284,-0.03824280857630372,2.1411196390683373E-4,0.02149175308850683,0.0033093617243690693,-0.01387258987880057,-0.005185628120854145],
// "xs":[2.88E7,2.952E7,3.024E7,3.096E7,3.168E7,3.24E7,3.312E7,3.384E7,3.456E7,3.528E7,3.6E7,3.672E7,3.744E7,3.816E7,3.888E7,3.96E7,4.032E7,4.104E7,4.176E7,4.248E7,4.32E7,4.392E7,4.464E7,4.536E7,4.608E7,4.68E7,4.752E7,4.824E7,4.896E7,4.968E7,5.04E7,5.112E7,5.184E7,5.256E7,5.328E7,5.4E7,5.472E7,5.544E7,5.616E7,5.688E7,5.76E7,5.832E7,5.904E7,5.976E7,6.048E7,6.12E7,6.192E7,6.264E7,6.336E7,6.408E7]
// },
// "ggsize":{
// "width":800.0,
// "height":400.0
// },
// "kind":"plot",
// "ggtoolbar":{
// },
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "xmin":4.5E7,
// "xmax":4.86E7,
// "position":"identity",
// "geom":"band",
// "tooltips":{
// "title":"Lunch Time",
// "lines":["^xmin - ^xmax","in any time zone"]
// },
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "color":"#1380A1",
// "size":2.0,
// "position":"identity",
// "geom":"line",
// "tooltips":{
// "lines":["Time:|@xs"],
// "formats":[{
// "field":"^x",
// "format":"%H:%M:%S"
// }]
// },
// "data":{
// }
// }],
// "theme":{
// "axis_title":"blank"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"time",
// "column":"xs"
// },{
// "type":"float",
// "column":"ys"
// }]
// },
// "spec_id":"1"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=20caa6ee-eb57-45ec-a564-363f5a56b782 width="100%" height="100%" style="max-width: 800.0px; max-height: 400.0px;" viewBox="0 0 800.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pxEFOH7 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pxEFOH7 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pxEFOH7 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxEFOH7 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pxEFOH7 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pxEFOH7 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxEFOH7 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pxEFOH7 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dMTlKAC .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxEFOH7 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pxEFOH7 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dMTlKAC .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxEFOH7 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxEFOH7 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dMTlKAC .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dMTlKAC .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dMTlKAC .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pxEFOH7">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L800.0 400.0 L800.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="34.40839515110224" y1="0.0" x2="34.40839515110224" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="104.62960974518853" y1="0.0" x2="104.62960974518853" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="174.85082433927482" y1="0.0" x2="174.85082433927482" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="245.07203893336123" y1="0.0" x2="245.07203893336123" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="315.2932535274475" y1="0.0" x2="315.2932535274475" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" s

// %% [markdown]
// #### Local Date
//
// `kotlinx.datetime.LocalDate` and `java.time.LocalDate` represent calendar dates without time information.
//
// `LocalDate` objects are inherently timezone-agnostic since they contain no time component - a date like "2024-01-15" represents the same calendar day regardless of timezone.
//
// The `datetime` scale renders these with default tooltips and scale breaks optimized for days or larger time units (weeks, months, years) depending on the data range.

// %%
import kotlinx.datetime.LocalDate
import kotlinx.datetime.DatePeriod
import kotlinx.datetime.plus

// This covers March 15 - May 3, 2025
val startDate = LocalDate(2025, 3, 15)
val xsDate = (0 until N).map { i ->
    startDate + DatePeriod(days = i)
}

val data = mapOf(
    "xs" to xsDate,
    "ys" to ys
)

(letsPlot(data = data) { x = "xs"; y = "ys" } +
    geomVLine(
        xintercept = LocalDate(2025, 4, 1),
        tooltips = layerTooltips()
            .title("April Fools' Day")
            .format("^xintercept", "%a, %b %e, %Y"),
        linetype = "dotted", 
        size = 1.5
    ) +
    geomLine(
        tooltips = layerTooltips()
            .line("Date:|@xs")
            .format("^x", "%b %d, %Y"),
        color = "#1380A1", 
        size = 2
    ) +
    ggtb() + 
    ggsize(800, 400) + 
    theme(axisTitle = "blank")
)
// Out:
//    <div id="ngVgcT"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("ngVgcT");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"xs",
// "y":"ys"
// },
// "data":{
// "ys":[0.05555244654696321,-0.31308975753180435,-0.10643462133932577,0.30009232333113145,0.17296312035336703,-0.22071111372232088,-0.13299780037831993,0.08650221374128016,0.07517308831149005,-0.03457732712883878,-0.053011702893076613,0.01613253296393087,0.05025135841149322,-0.006087168607620953,-0.06373424084254278,-0.007203131933992198,0.09508414134219141,0.030997473081211188,-0.08736932916274698,-0.03395485486461525,0.042462211485356505,0.02498071850034842,-0.021846761376655595,-0.021667111013930086,0.014102019771655625,0.02429063240307002,-0.010820138233714487,-0.03549936052176265,0.0074705086233501,0.05839869912786762,0.002691520004471486,-0.055042584594207355,-0.010168953244153327,0.02907608751881987,0.010370233132486369,-0.01702935417966255,-0.010922022515953079,0.012888239469640033,0.014111413375350355,-0.01242410772629795,-0.02311035299814162,0.013738836902986275,0.040600698558063315,-0.009436090766507284,-0.03824280857630372,2.1411196390683373E-4,0.02149175308850683,0.0033093617243690693,-0.01387258987880057,-0.005185628120854145],
// "xs":[1.7419968E12,1.7420832E12,1.7421696E12,1.742256E12,1.7423424E12,1.7424288E12,1.7425152E12,1.7426016E12,1.742688E12,1.7427744E12,1.7428608E12,1.7429472E12,1.7430336E12,1.74312E12,1.7432064E12,1.7432928E12,1.7433792E12,1.7434656E12,1.743552E12,1.7436384E12,1.7437248E12,1.7438112E12,1.7438976E12,1.743984E12,1.7440704E12,1.7441568E12,1.7442432E12,1.7443296E12,1.744416E12,1.7445024E12,1.7445888E12,1.7446752E12,1.7447616E12,1.744848E12,1.7449344E12,1.7450208E12,1.7451072E12,1.7451936E12,1.74528E12,1.7453664E12,1.7454528E12,1.7455392E12,1.7456256E12,1.745712E12,1.7457984E12,1.7458848E12,1.7459712E12,1.7460576E12,1.746144E12,1.7462304E12]
// },
// "ggsize":{
// "width":800.0,
// "height":400.0
// },
// "kind":"plot",
// "ggtoolbar":{
// },
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "size":1.5,
// "linetype":"dotted",
// "position":"identity",
// "xintercept":1.7434656E12,
// "geom":"vline",
// "tooltips":{
// "title":"April Fools' Day",
// "formats":[{
// "field":"^xintercept",
// "format":"%a, %b %e, %Y"
// }]
// },
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "color":"#1380A1",
// "size":2.0,
// "position":"identity",
// "geom":"line",
// "tooltips":{
// "lines":["Date:|@xs"],
// "formats":[{
// "field":"^x",
// "format":"%b %d, %Y"
// }]
// },
// "data":{
// }
// }],
// "theme":{
// "axis_title":"blank"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"date",
// "column":"xs"
// },{
// "type":"float",
// "column":"ys"
// }]
// },
// "spec_id":"3"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=615ab5d1-e7a5-4bf8-be37-cfbcba028b6a width="100%" height="100%" style="max-width: 800.0px; max-height: 400.0px;" viewBox="0 0 800.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pcac0DY .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pcac0DY .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pcac0DY .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pcac0DY .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pcac0DY .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pcac0DY .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pcac0DY .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pcac0DY .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dp0UNs5 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pcac0DY .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pcac0DY .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dp0UNs5 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pcac0DY .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pcac0DY .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dp0UNs5 .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dp0UNs5 .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dp0UNs5 .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pcac0DY">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L800.0 400.0 L800.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="62.49688098876504" y1="0.0" x2="62.49688098876504" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="160.80658142047469" y1="0.0" x2="160.80658142047469" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="259.11628185218433" y1="0.0" x2="259.11628185218433" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>

// %% [markdown]
// #### Date-Time
//
// `kotlinx.datetime.LocalDateTime`, `java.time.ZonedDateTime`, and `java.time.OffsetDateTime` represent both date and time information, either timezone-naive or timezone-aware.
//
// The datetime scale automatically adapts tooltips and scale breaks based on the data's temporal resolution.
//
// **Timezone handling:** If no timezone information is present (`LocalDateTime`), Lets-Plot assumes UTC timezone. <br>
// For timezone-aware datetime objects (`ZonedDateTime`/`OffsetDateTime`), the timezone information from the data is preserved and used for rendering.

// %%
import java.time.ZonedDateTime
import java.time.ZoneId
import java.time.Instant

// Berlin DST transition: March 30, 2025 at 2:00 AM
// Cover ±3 days: March 27 - April 2, 2025 (6 days total)

// Generate equally spaced UNIX timestamps (in seconds)
val startTimestamp = ZonedDateTime.of(2025, 3, 27, 0, 0, 0, 0, ZoneId.of("UTC")).toEpochSecond()
val endTimestamp = ZonedDateTime.of(2025, 4, 2, 23, 59, 0, 0, ZoneId.of("UTC")).toEpochSecond()
val unixTimestamps = (0 until N).map { i -> 
    startTimestamp + (endTimestamp - startTimestamp) * i / (N - 1) 
}

// Convert to ZonedDateTime with Berlin timezone
val xsDatetime = unixTimestamps.map { timestamp ->
    Instant.ofEpochSecond(timestamp).atZone(ZoneId.of("Europe/Berlin"))
}

val data = mapOf(
    "xs" to xsDatetime,
    "ys" to ys
)

val p = letsPlot(data = data) { x = "xs"; y = "ys" } +
    geomVLine(
        xintercept = ZonedDateTime.of(2025, 3, 30, 1, 59, 59, 0, ZoneId.of("Europe/Berlin")),
        tooltips = layerTooltips()
            .title("Berlin \"spring forward\" transition")
            .line("^xintercept").format("^xintercept", "%b %d, %Y %H:%M:%S")
            .line("2:00 AM → 3:00 AM"),
        linetype = "dotted", 
        size = 1.5
    ) +
    geomLine(
        tooltips = layerTooltips()
            .line("@xs")
            .format("^x", "%b %d, %Y %H:%M"),
        color = "#1380A1", 
        size = 2
    ) +
    ggtb() + 
    ggsize(800, 400) + 
    theme(axisTitle = "blank")

p
// Out:
//    <div id="1w4paV"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("1w4paV");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"xs",
// "y":"ys"
// },
// "data":{
// "ys":[0.05555244654696321,-0.31308975753180435,-0.10643462133932577,0.30009232333113145,0.17296312035336703,-0.22071111372232088,-0.13299780037831993,0.08650221374128016,0.07517308831149005,-0.03457732712883878,-0.053011702893076613,0.01613253296393087,0.05025135841149322,-0.006087168607620953,-0.06373424084254278,-0.007203131933992198,0.09508414134219141,0.030997473081211188,-0.08736932916274698,-0.03395485486461525,0.042462211485356505,0.02498071850034842,-0.021846761376655595,-0.021667111013930086,0.014102019771655625,0.02429063240307002,-0.010820138233714487,-0.03549936052176265,0.0074705086233501,0.05839869912786762,0.002691520004471486,-0.055042584594207355,-0.010168953244153327,0.02907608751881987,0.010370233132486369,-0.01702935417966255,-0.010922022515953079,0.012888239469640033,0.014111413375350355,-0.01242410772629795,-0.02311035299814162,0.013738836902986275,0.040600698558063315,-0.009436090766507284,-0.03824280857630372,2.1411196390683373E-4,0.02149175308850683,0.0033093617243690693,-0.01387258987880057,-0.005185628120854145],
// "xs":[1.7430336E12,1.743045941E12,1.743058283E12,1.743070624E12,1.743082966E12,1.743095308E12,1.743107649E12,1.743119991E12,1.743132333E12,1.743144674E12,1.743157016E12,1.743169357E12,1.743181699E12,1.743194041E12,1.743206382E12,1.743218724E12,1.743231066E12,1.743243407E12,1.743255749E12,1.743268091E12,1.743280432E12,1.743292774E12,1.743305115E12,1.743317457E12,1.743329799E12,1.74334214E12,1.743354482E12,1.743366824E12,1.743379165E12,1.743391507E12,1.743403848E12,1.74341619E12,1.743428532E12,1.743440873E12,1.743453215E12,1.743465557E12,1.743477898E12,1.74349024E12,1.743502582E12,1.743514923E12,1.743527265E12,1.743539606E12,1.743551948E12,1.74356429E12,1.743576631E12,1.743588973E12,1.743601315E12,1.743613656E12,1.743625998E12,1.74363834E12]
// },
// "ggsize":{
// "width":800.0,
// "height":400.0
// },
// "kind":"plot",
// "ggtoolbar":{
// },
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "size":1.5,
// "linetype":"dotted",
// "position":"identity",
// "xintercept":1.743296399E12,
// "geom":"vline",
// "tooltips":{
// "formats":[{
// "field":"^xintercept",
// "format":"%b %d, %Y %H:%M:%S"
// }],
// "title":"Berlin \"spring forward\" transition",
// "lines":["^xintercept","2:00 AM → 3:00 AM"]
// },
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "color":"#1380A1",
// "size":2.0,
// "position":"identity",
// "geom":"line",
// "tooltips":{
// "lines":["@xs"],
// "formats":[{
// "field":"^x",
// "format":"%b %d, %Y %H:%M"
// }]
// },
// "data":{
// }
// }],
// "theme":{
// "axis_title":"blank"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"datetime",
// "time_zone":"Europe/Berlin",
// "column":"xs"
// },{
// "type":"float",
// "column":"ys"
// }]
// },
// "spec_id":"5"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=d25c7f00-c265-46ed-8f38-021681d0115a width="100%" height="100%" style="max-width: 800.0px; max-height: 400.0px;" viewBox="0 0 800.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pSqwLnN .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pSqwLnN .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pSqwLnN .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pSqwLnN .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pSqwLnN .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pSqwLnN .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pSqwLnN .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pSqwLnN .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ddHVlWa .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pSqwLnN .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pSqwLnN .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ddHVlWa .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pSqwLnN .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pSqwLnN .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ddHVlWa .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ddHVlWa .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ddHVlWa .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pSqwLnN">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L800.0 400.0 L800.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="30.31175122014247" y1="0.0" x2="30.31175122014247" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="128.6312055659946" y1="0.0" x2="128.6312055659946" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">

// %% [markdown]
// #### Zoomed-in View: Berlin Start of DST Transition Details
//
// This plot zooms into the DST transition period: ±8 hours around March 30, 2025 at 2:00 AM.
//
// Notice that the time 2025-03-30 02:00:00 through 2025-03-30 02:59:59 does not exist in Europe/Berlin timezone - clocks spring forward directly from 01:59:59 to 03:00:00, creating a gap in the timeline.

// %%
p + coordCartesian(
    xlim = Pair(
        ZonedDateTime.of(2025, 3, 29, 21, 0, 0, 0, ZoneId.of("Europe/Berlin")),
        ZonedDateTime.of(2025, 3, 30, 8, 0, 0, 0, ZoneId.of("Europe/Berlin"))
    )
)
// Out:
//    <div id="eMeC4K"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("eMeC4K");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"xs",
// "y":"ys"
// },
// "coord":{
// "name":"cartesian",
// "xlim":[1.7432784E12,1.7433144E12],
// "flip":false
// },
// "data":{
// "ys":[0.05555244654696321,-0.31308975753180435,-0.10643462133932577,0.30009232333113145,0.17296312035336703,-0.22071111372232088,-0.13299780037831993,0.08650221374128016,0.07517308831149005,-0.03457732712883878,-0.053011702893076613,0.01613253296393087,0.05025135841149322,-0.006087168607620953,-0.06373424084254278,-0.007203131933992198,0.09508414134219141,0.030997473081211188,-0.08736932916274698,-0.03395485486461525,0.042462211485356505,0.02498071850034842,-0.021846761376655595,-0.021667111013930086,0.014102019771655625,0.02429063240307002,-0.010820138233714487,-0.03549936052176265,0.0074705086233501,0.05839869912786762,0.002691520004471486,-0.055042584594207355,-0.010168953244153327,0.02907608751881987,0.010370233132486369,-0.01702935417966255,-0.010922022515953079,0.012888239469640033,0.014111413375350355,-0.01242410772629795,-0.02311035299814162,0.013738836902986275,0.040600698558063315,-0.009436090766507284,-0.03824280857630372,2.1411196390683373E-4,0.02149175308850683,0.0033093617243690693,-0.01387258987880057,-0.005185628120854145],
// "xs":[1.7430336E12,1.743045941E12,1.743058283E12,1.743070624E12,1.743082966E12,1.743095308E12,1.743107649E12,1.743119991E12,1.743132333E12,1.743144674E12,1.743157016E12,1.743169357E12,1.743181699E12,1.743194041E12,1.743206382E12,1.743218724E12,1.743231066E12,1.743243407E12,1.743255749E12,1.743268091E12,1.743280432E12,1.743292774E12,1.743305115E12,1.743317457E12,1.743329799E12,1.74334214E12,1.743354482E12,1.743366824E12,1.743379165E12,1.743391507E12,1.743403848E12,1.74341619E12,1.743428532E12,1.743440873E12,1.743453215E12,1.743465557E12,1.743477898E12,1.74349024E12,1.743502582E12,1.743514923E12,1.743527265E12,1.743539606E12,1.743551948E12,1.74356429E12,1.743576631E12,1.743588973E12,1.743601315E12,1.743613656E12,1.743625998E12,1.74363834E12]
// },
// "ggsize":{
// "width":800.0,
// "height":400.0
// },
// "kind":"plot",
// "ggtoolbar":{
// },
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "size":1.5,
// "linetype":"dotted",
// "position":"identity",
// "xintercept":1.743296399E12,
// "geom":"vline",
// "tooltips":{
// "formats":[{
// "field":"^xintercept",
// "format":"%b %d, %Y %H:%M:%S"
// }],
// "title":"Berlin \"spring forward\" transition",
// "lines":["^xintercept","2:00 AM → 3:00 AM"]
// },
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "color":"#1380A1",
// "size":2.0,
// "position":"identity",
// "geom":"line",
// "tooltips":{
// "lines":["@xs"],
// "formats":[{
// "field":"^x",
// "format":"%b %d, %Y %H:%M"
// }]
// },
// "data":{
// }
// }],
// "theme":{
// "axis_title":"blank"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"datetime",
// "time_zone":"Europe/Berlin",
// "column":"xs"
// },{
// "type":"float",
// "column":"ys"
// }]
// },
// "spec_id":"7"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=7cd8af44-fafe-4465-9a9b-c594566f6373 width="100%" height="100%" style="max-width: 800.0px; max-height: 400.0px;" viewBox="0 0 800.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pF0ULZx .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pF0ULZx .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pF0ULZx .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pF0ULZx .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pF0ULZx .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pF0ULZx .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pF0ULZx .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pF0ULZx .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dNvnpIc .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pF0ULZx .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pF0ULZx .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dNvnpIc .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pF0ULZx .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pF0ULZx .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dNvnpIc .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dNvnpIc .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dNvnpIc .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pF0ULZx">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L800.0 400.0 L800.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="0.0" x2="0.0" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="75.69846933335066" y1="0.0" x2="75.69846933335066" y2="369.0" stroke="rgb(233,233,233)" strok

// %% [markdown]
// #### Berlin End of DST Transition Details
//
// The mirroring phenomenon can be observed during Berlin's end of DST transition: around October 26, 2025 at 2:00 AM.
//
// Notice that the time 2025-10-26 02:00:00 through 2025-10-26 02:59:59 appears twice in Europe/Berlin timezone - clocks fall back from 02:59:59 to 02:00:00, creating a duplication in the timeline where the same hour occurs twice.

// %%
// Berlin DST transition back: October 26, 2025 at 3:00 AM → 2:00 AM

// Generate equally spaced UNIX timestamps (in seconds)
val startTimestamp = ZonedDateTime.of(2025, 10, 23, 0, 0, 0, 0, ZoneId.of("UTC")).toEpochSecond()
val endTimestamp = ZonedDateTime.of(2025, 10, 29, 23, 59, 0, 0, ZoneId.of("UTC")).toEpochSecond()
val unixTimestamps = (0 until N).map { i -> 
    startTimestamp + (endTimestamp - startTimestamp) * i / (N - 1) 
}

// Convert to ZonedDateTime with Berlin timezone
val xsDatetime = unixTimestamps.map { timestamp ->
    Instant.ofEpochSecond(timestamp).atZone(ZoneId.of("Europe/Berlin"))
}

val data = mapOf(
    "xs" to xsDatetime,
    "ys" to ys
)

val p = letsPlot(data = data) { x = "xs"; y = "ys" } +
    geomVLine(
        xintercept = Instant.ofEpochSecond(
            ZonedDateTime.of(2025, 10, 26, 0, 59, 59, 0, ZoneId.of("UTC")).toEpochSecond()
        ).atZone(ZoneId.of("Europe/Berlin")),
        tooltips = layerTooltips()
            .title("Berlin \"fall back\" transition")
            .line("^xintercept").format("^xintercept", "%b %d, %Y %H:%M:%S")
            .line("3:00 AM → 2:00 AM"),
        linetype = "dotted", 
        size = 1.5
    ) +
    geomLine(
        tooltips = layerTooltips()
            .line("@xs")
            .format("^x", "%b %d, %Y %H:%M"),
        color = "#1380A1", 
        size = 2
    ) +
    ggtb() + 
    ggsize(800, 400) + 
    theme(axisTitle = "blank")

p + coordCartesian(
    xlim = Pair(
        ZonedDateTime.of(2025, 10, 25, 22, 0, 0, 0, ZoneId.of("Europe/Berlin")),
        ZonedDateTime.of(2025, 10, 26, 8, 0, 0, 0, ZoneId.of("Europe/Berlin"))
    )
)
// Out:
//    <div id="FvRjFH"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("FvRjFH");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"xs",
// "y":"ys"
// },
// "coord":{
// "name":"cartesian",
// "xlim":[1.7614224E12,1.761462E12],
// "flip":false
// },
// "data":{
// "ys":[0.05555244654696321,-0.31308975753180435,-0.10643462133932577,0.30009232333113145,0.17296312035336703,-0.22071111372232088,-0.13299780037831993,0.08650221374128016,0.07517308831149005,-0.03457732712883878,-0.053011702893076613,0.01613253296393087,0.05025135841149322,-0.006087168607620953,-0.06373424084254278,-0.007203131933992198,0.09508414134219141,0.030997473081211188,-0.08736932916274698,-0.03395485486461525,0.042462211485356505,0.02498071850034842,-0.021846761376655595,-0.021667111013930086,0.014102019771655625,0.02429063240307002,-0.010820138233714487,-0.03549936052176265,0.0074705086233501,0.05839869912786762,0.002691520004471486,-0.055042584594207355,-0.010168953244153327,0.02907608751881987,0.010370233132486369,-0.01702935417966255,-0.010922022515953079,0.012888239469640033,0.014111413375350355,-0.01242410772629795,-0.02311035299814162,0.013738836902986275,0.040600698558063315,-0.009436090766507284,-0.03824280857630372,2.1411196390683373E-4,0.02149175308850683,0.0033093617243690693,-0.01387258987880057,-0.005185628120854145],
// "xs":[1.7611776E12,1.761189941E12,1.761202283E12,1.761214624E12,1.761226966E12,1.761239308E12,1.761251649E12,1.761263991E12,1.761276333E12,1.761288674E12,1.761301016E12,1.761313357E12,1.761325699E12,1.761338041E12,1.761350382E12,1.761362724E12,1.761375066E12,1.761387407E12,1.761399749E12,1.761412091E12,1.761424432E12,1.761436774E12,1.761449115E12,1.761461457E12,1.761473799E12,1.76148614E12,1.761498482E12,1.761510824E12,1.761523165E12,1.761535507E12,1.761547848E12,1.76156019E12,1.761572532E12,1.761584873E12,1.761597215E12,1.761609557E12,1.761621898E12,1.76163424E12,1.761646582E12,1.761658923E12,1.761671265E12,1.761683606E12,1.761695948E12,1.76170829E12,1.761720631E12,1.761732973E12,1.761745315E12,1.761757656E12,1.761769998E12,1.76178234E12]
// },
// "ggsize":{
// "width":800.0,
// "height":400.0
// },
// "kind":"plot",
// "ggtoolbar":{
// },
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "size":1.5,
// "linetype":"dotted",
// "position":"identity",
// "xintercept":1.761440399E12,
// "geom":"vline",
// "tooltips":{
// "formats":[{
// "field":"^xintercept",
// "format":"%b %d, %Y %H:%M:%S"
// }],
// "title":"Berlin \"fall back\" transition",
// "lines":["^xintercept","3:00 AM → 2:00 AM"]
// },
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "color":"#1380A1",
// "size":2.0,
// "position":"identity",
// "geom":"line",
// "tooltips":{
// "lines":["@xs"],
// "formats":[{
// "field":"^x",
// "format":"%b %d, %Y %H:%M"
// }]
// },
// "data":{
// }
// }],
// "theme":{
// "axis_title":"blank"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"datetime",
// "time_zone":"Europe/Berlin",
// "column":"xs"
// },{
// "type":"float",
// "column":"ys"
// }]
// },
// "spec_id":"9"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=ff84a714-5fd1-41e4-9b50-dff3fd86b844 width="100%" height="100%" style="max-width: 800.0px; max-height: 400.0px;" viewBox="0 0 800.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pgg1dZl .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pgg1dZl .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgg1dZl .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgg1dZl .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pgg1dZl .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgg1dZl .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgg1dZl .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgg1dZl .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dGNW61z .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgg1dZl .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgg1dZl .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dGNW61z .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgg1dZl .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgg1dZl .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dGNW61z .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dGNW61z .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dGNW61z .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pgg1dZl">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L800.0 400.0 L800.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="0.0" x2="0.0" y2="369.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="68.81679030507803" y1="0.0" x2="68.81679030507803" y2="369.0" stroke="rgb(233,233,233)" stroke-opac
